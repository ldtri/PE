# %%
manifest_api = ''
manifest_mysql = ''
makefile = ''
name = 'notasquare-it-app-templates'
with open('../Desktop/manifest.yaml', 'r') as f:
    _data = f.read()
    manifest_api = _data.replace('##NAME##', name)
    
with open('../Desktop/manifest-mysql.yaml', 'r') as f:
    _data = f.read()
    manifest_mysql = _data.replace('##NAME##', name)
with open('../Desktop/Makefile', 'r') as f:
    _data = f.read()
    manifest_mysql = _data.replace('##NAME##', name)
f.closed
print(manifest_api)
print('-----')
print(manifest_mysql)
# Out:
# apiVersion:                                extensions/v1beta1
# kind:                                      ReplicaSet
# metadata:
#   namespace:                               notasquare-it
#   name:                                    nas-yaml-replicaset
#   labels:
#     name:                                  nas-yaml-replicaset
#     code:                                  nas-yaml
# spec:
#   replicas:                                1
#   template:
#     metadata:
#       labels:
#         name:                              nas-yaml-pod
#         code:                              nas-yaml
#     spec:
#       containers:
#       - name:                              master
#         image:                             registry.novogenialab.com/notasquare/app-templates-api/test:latest
#         resources:
#           requests:
#             cpu:                           25m
#             memory:                        50Mi
#           limits:
#             cpu:                           1000m
#             memory:                        2000Mi
#         env:
#         - name:                            MYSQL_NAME
#           value:                           api_db
#         - name:                            MYSQL_USER
#           value:                           root
#         - name:                            MYSQL_PASS
#           value:                           '123456'
#         - name:                            MYSQL_HOST
#           value:                           nas-yaml-mysql-service
#         - name:                            MYSQL_PORT
#           value:                           '3306'
# ---
# apiVersion:                                v1
# kind:                                      Service
# metadata:
#   namespace:                               notasquare-it
#   name:                                    nas-yaml-service
#   labels:
#     name:                                  nas-yaml-service
#     code:                                  nas-yaml
# spec:
#   ports:
#   - port:                                  80
#     targetPort:                            80
#   selector:
#     name:                                  nas-yaml-pod
#     code:                                  nas-yaml
# ---
# apiVersion:                                extensions/v1beta1
# kind:                                      Ingress
# metadata:
#   namespace:                               notasquare-it
#   name:                                    nas-yaml-ingress
#   labels:
#     name:                                  nas-yaml-ingress
#     code:                                  nas-yaml
#   annotations:
#     ingress.kubernetes.io/proxy-body-size: "100m"
# spec:
#   rules:
#     - host:                                app-templates-api.nvit.test.notasquare.vn
#       http:
#         paths:
#           - path:                          /
#             backend:
#               serviceName:                 nas-yaml-service
#               servicePort:                 80
#
# -----
# apiVersion:                    v1
# kind:                          PersistentVolumeClaim
# metadata:
#   namespace:                   notasquare-it
#   name:                        nas-yaml-mysql-pvc
#   labels:
#     name:                      nas-yaml-mysql-pvc
#     code:                      nas-yaml-mysql
# spec:
#   accessModes:
#     - ReadWriteOnce
#   resources:
#     requests:
#       storage:                 5Gi
# ---
# apiVersion:                    extensions/v1beta1
# kind:                          ReplicaSet
# metadata:
#   namespace:                   notasquare-it
#   name:                        nas-yaml-mysql-replicaset
#   labels:
#     name:                      nas-yaml-mysql-replicaset
#     code:                      nas-yaml-mysql
# spec:
#   replicas:                    1
#   template:
#     metadata:
#       labels:
#         name:                  nas-yaml-mysql-pod
#         code:                  nas-yaml-mysql
#     spec:
#       containers:
#       - name:                  mysql
#         image:                 registry.novogenialab.com/notasquare-zero/images/standard-mysql:0.1
#         resources:
#           requests:
#             cpu:               25m
#             memory:            50Mi
#           limits:
#             cpu:               200m
#             memory:            400Mi
#         ports:
#         - containerPort:       3306
#         volumeMounts:
#         - name:                nas-yaml-mysql-ps
#           mountPath:           /var/lib/mysql
#       volumes:
#       - name:                  nas-yaml-mysql-ps
#         persistentVolumeClaim:
#           claimName:           nas-yaml-mysql-pvc
# ---
# apiVersion:                    v1
# kind:                          Service
# metadata:
#   namespace:                   notasquare-it
#   name:                        nas-yaml-mysql-service
#   labels:
#     name:                      nas-yaml-mysql-service
#     code:                      nas-yaml-mysql
# spec:
#   ports:
#   - port:                      3306
#     targetPort:                3306
#   selector:
#     name:                      nas-yaml-mysql-pod
