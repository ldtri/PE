# %%
manifest_api = ''
manifest_mysql = ''
makefile = ''
name = 'app-templates-api'
with open('../Desktop/manifest.yaml', 'r') as f:
    _data = f.read()
    manifest_api = _data.replace('##NAME##', name)
f.closed    
with open('../Desktop/manifest-mysql.yaml', 'r') as f:
    _data = f.read()
    manifest_mysql = _data.replace('##NAME##', name)
f.closed
with open('../Desktop/Makefile', 'r') as f:
    _data = f.read()
    manifest_mysql = _data.replace('##NAME##', name)
f.closed
# Out:
# =====================
# apiVersion:                                extensions/v1beta1
# kind:                                      ReplicaSet
# metadata:
#   namespace:                               notasquare-it
#   name:                                    app-templates-api-replicaset
#   labels:
#     name:                                  app-templates-api-replicaset
#     code:                                  app-templates-api
# spec:
#   replicas:                                1
#   template:
#     metadata:
#       labels:
#         name:                              app-templates-api-pod
#         code:                              app-templates-api
#     spec:
#       containers:
#       - name:                              master
#         image:                             registry.novogenialab.com/notasquare/app-templates-api/test:latest
#         resources:
#           requests:
#             cpu:                           25m
#             memory:                        50Mi
#           limits:
#             cpu:                           1000m
#             memory:                        2000Mi
#         env:
#         - name:                            MYSQL_NAME
#           value:                           api_db
#         - name:                            MYSQL_USER
#           value:                           root
#         - name:                            MYSQL_PASS
#           value:                           '123456'
#         - name:                            MYSQL_HOST
#           value:                           app-templates-api-mysql-service
#         - name:                            MYSQL_PORT
#           value:                           '3306'
# ---
# apiVersion:                                v1
# kind:                                      Service
# metadata:
#   namespace:                               notasquare-it
#   name:                                    app-templates-api-service
#   labels:
#     name:                                  app-templates-api-service
#     code:                                  app-templates-api
# spec:
#   ports:
#   - port:                                  80
#     targetPort:                            80
#   selector:
#     name:                                  app-templates-api-pod
#     code:                                  app-templates-api
# ---
# apiVersion:                                extensions/v1beta1
# kind:                                      Ingress
# metadata:
#   namespace:                               notasquare-it
#   name:                                    app-templates-api-ingress
#   labels:
#     name:                                  app-templates-api-ingress
#     code:                                  app-templates-api
#   annotations:
#     ingress.kubernetes.io/proxy-body-size: "100m"
# spec:
#   rules:
#     - host:                                app-templates-api.nvit.test.notasquare.vn
#       http:
#         paths:
#           - path:                          /
#             backend:
#               serviceName:                 app-templates-api-service
#               servicePort:                 80
#
# =====================
# REGISTRY=registry.novogenialab.com
# NOTASQUARE_APP_TEMPLATES_API_HOME=$(APP_HOME)/app-templates-api
# NOTASQUARE_APP_TEMPLATES_API_HOST_PORT=8436
# NOTASQUARE_APP_TEMPLATES_MYSQL_HOST_PORT=3536
#
# # DEV
# dev-build:
# 	sudo docker build -f docker/Dockerfile-dev -t notasquare/app-templates-api/dev .
#
# dev-create-storage:
# 	sudo docker run -d --name=notasquare.app-templates-api.mysql.storage \
# 		registry.novogenialab.com/notasquare-zero/images/standard-mysql:0.1 true
#
# dev-clear-storage:
# 	-sudo docker stop notasquare.app-templates-api.mysql.storage
# 	-sudo docker rm notasquare.app-templates-api.mysql.storage
#
# dev-deploy:
# 	sudo docker run -d --name=notasquare.app-templates-api.mysql \
# 		--volumes-from=notasquare.app-templates-api.mysql.storage \
# 		-p $(NOTASQUARE_APP_TEMPLATES_MYSQL_HOST_PORT):3306 \
# 		registry.novogenialab.com/notasquare-zero/images/standard-mysql:0.1
#
# 	sudo docker run -d --name=notasquare.app-templates-api.web \
# 		-v $(NOTASQUARE_APP_TEMPLATES_API_HOME)/src/www/:/opt/www/ \
# 		-p $(NOTASQUARE_APP_TEMPLATES_API_HOST_PORT):80 \
# 		--link notasquare.app-templates-api.mysql:mysql \
# 		notasquare/app-templates-api/dev
#
# dev-start:
# 	sudo docker start notasquare.app-templates-api.mysql
# 	sudo docker start notasquare.app-templates-api.web
#
# dev-stop:
# 	sudo docker stop notasquare.app-templates-api.mysql
# 	sudo docker stop notasquare.app-templates-api.web
#
# dev-clean:
# 	-sudo docker stop notasquare.app-templates-api.mysql
# 	-sudo docker stop notasquare.app-templates-api.web
# 	-sudo docker rm notasquare.app-templates-api.mysql
# 	-sudo docker rm notasquare.app-templates-api.web
#
# dev-ssh-mysql:
# 	sudo docker exec -it notasquare.app-templates-api.mysql bash
#
# dev-ssh-api:
# 	sudo docker exec -it notasquare.app-templates-api.web bash
#
# # Test
# test-release:
# 	sudo docker build -f docker/Dockerfile-dev -t notasquare/app-templates-api/dev .
# 	sudo docker build --no-cache -f docker/Dockerfile-test -t notasquare/app-templates-api/test .
# 	sudo docker tag notasquare/app-templates-api/test $(REGISTRY)/notasquare/app-templates-api/test
# 	sudo docker push $(REGISTRY)/notasquare/app-templates-api/test
#
# test-deploy-mysql:
# 	kubectl apply -f deploy/test/manifest-mysql.yaml
#
# test-deploy:
# 	-kubectl delete -f deploy/test/manifest.yaml
# 	kubectl apply -f deploy/test/manifest.yaml
